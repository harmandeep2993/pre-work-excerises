# %%
x1 = input("Please enter an integer number: ")
x2 = input("Please enter another integer number: ")

print("The first input x1: ",x1)
print("\nData type of x1: ", type(x1))
print("\nThe second input x2: ",x2)
print("\nData type of x2: ", type(x2))
# Out:
# The first input x1:  3
#
# Data type of x1:  <class 'str'>
#
# The second input x2:  5
#
# Data type of x2:  <class 'str'>

# %%
x1 = int(input("Please enter an integer number: "))
x2 = int(input("Please enter another integer number: "))

print("The first input x1: ",x1)
print("\nData type of x1: ", type(x1))
print("\nThe second input x2: ",x2)
print("\nData type of x2: ", type(x2))
# Out:
# The first input x1:  3
#
# Data type of x1:  <class 'int'>
#
# The second input x2:  5
#
# Data type of x2:  <class 'int'>

# %%
x1==x2
# Out:
# False

# %%
x1>x2
# Out:
# False

# %%
x2>x1
# Out:
# True

# %%
x1!=x2
# Out:
# True

# %%
x3=x2-x1

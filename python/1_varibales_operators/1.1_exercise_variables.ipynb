# %% [markdown]
# ### 1. Exercise - Data Types

# %% [markdown]
# 1.1 For the given variables, use the type() function in Python to check their data types:

# %%
x1= 1.1
type(x1)
# Out:
# float

# %%
x2 = "Ironhack"
type(x2)
# Out:
# str

# %%
x3 = "1.1"
type(x3)
# Out:
# str

# %%
x4 = True
type(x4)
# Out:
# bool

# %%
x5 = "True"
type(x5)
# Out:
# str

# %%
x6 = -1
type(x6)
# Out:
# int

# %% [markdown]
# 1.2 What is the difference between variables x1 and x3?

# %%
type(x1)
# Out:
# float

# %%
type(x3)
# Out:
# str

# %% [markdown]
# - "x1" is a float data type whereas as "x3" is string data type.

# %% [markdown]
# 1.3 What happens if you subtract x3 from x1?

# %%
x3-x1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x3-x1
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %% [markdown]
# When substracting x3 from x1 will throw an error of unsupported operand type because of different data type. x1 is float data type and x3 is str, which means string can not be substracted from the float.

# %% [markdown]
# 1.4 What is the difference between variables x4 and x5?

# %%
x4
# Out:
# True

# %%
type(x4)
# Out:
# bool

# %%
x5
# Out:
# 'True'

# %%
type(x5)
# Out:
# str

# %% [markdown]
# - The difference between ``x4`` and ``x5`` is that ``x4`` is ``bool`` data type where as ``x5`` is ``str`` data type.

# %% [markdown]
# 1. 5 What happens if you subtract x5 from x4?

# %%
x4-x5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 x4-x5
#
# TypeError: unsupported operand type(s) for -: 'bool' and 'str'

# %% [markdown]
# This operation is not also possible due to different data types.

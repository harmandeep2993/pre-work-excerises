# %% [markdown]
# # 3.2.1 Dictionary Practise Question

# %% [markdown]
# Use the dictionary given below. This is a dictionary that shows the frequency of the words in a text paragraph. The keys are the words, and the values are its frequency.
#
# Given dictionary:
#
# ``word_freq = {'love': 25, 'conversation': 1, 'every': 6, "we're": 1, 'plate': 1, 'sour': 1, 'jukebox': 1, 'now': 11, 'taxi': 1, 'fast': 1, 'bag': 1, 'man': 1, 'push': 3, 'baby': 14, 'going': 1, 'you': 16, "don't": 2, 'one': 1, 'mind': 2, 'backseat': 1, 'friends': 1, 'then': 3, 'know': 2}``
#
# Answer the following questions:
#
# - How many *key-value* pairs are in this dictionary?
# - What *keys* are present in this dictionary?
# - What is the frequency of following words in the dictionary:
#     - 'friends'
#     - 'taxi'
#     - 'jukebox'
# - Is the word `begin` present in the dictionary?
# - Add the following words and their frequencies to the dictionary:
#     - 'begin': 1
#     - 'start': 2
#     - 'over': 1
#     - 'body': 17
# - Use the method `list()` to convert the result from `word_freq.keys()` to a list: `list(word_freq.keys())`.
#   - Store the results of the above code in a variable called `word_list`.
#   - What is the first word in `word_list`? What is the frequency of that word?
#   - What is the last word in `word_list`? What is the frequency of that word?

# %%
# Define the dictionary
word_freq = {'love': 25, 'conversation': 1, 'every': 6, "we're": 1, 'plate': 1, 'sour': 1, 'jukebox': 1,
             'now': 11, 'taxi': 1, 'fast': 1, 'bag': 1, 'man': 1, 'push': 3, 'baby': 14, 'going': 1,
             'you': 16, "don't": 2, 'one': 1, 'mind': 2, 'backseat': 1, 'friends': 1, 'then': 3, 'know': 2
}

# %% [markdown]
# 1. How many key-value pairs are in the dictionary?

# %%
# Key-value pairs in this dictionary?
print("Number of key-value pairs in the dictionary: ", len(word_freq))
# Out:
# Number of key-value pairs in the dictionary:  23

# %% [markdown]
# 2. What keys are present in the dictionary?

# %%
# keys in the dictionary
print("Keys in the dictionary:")
print(word_freq.keys())
# Out:
# Keys in the dictionary:
# dict_keys(['love', 'conversation', 'every', "we're", 'plate', 'sour', 'jukebox', 'now', 'taxi', 'fast', 'bag', 'man', 'push', 'baby', 'going', 'you', "don't", 'one', 'mind', 'backseat', 'friends', 'then', 'know'])

# %% [markdown]
# 3. Frequency of specific words

# %%
# Frequency of friends, taxi, jukebox in the dictionary

print("Frequency of 'friends':", word_freq.get('friends', 0))
print("Frequency of 'taxi':", word_freq.get('taxi', 0))
print("Frequency of 'jukebox':", word_freq.get('jukebox', 0))
# Out:
# Frequency of 'friends': 1
# Frequency of 'taxi': 1
# Frequency of 'jukebox': 1

# %% [markdown]
# 4. Is the word 'begin' present in the dictionary?

# %%
# check word `begin` present in the dictionary
search_word= "begin" 

if search_word in word_freq:
    print(f"Yes, word \"{search_word}\" is present database.")

else:
    print(f"No, word \"{search_word}\" is not present database.")
# Out:
# No, word "begin" is not present database.

# %% [markdown]
# 5. Add new words and their frequencies

# %%
# add new key-value pairs in the dictionary

word_freq['begin'] = 1
word_freq['start'] = 2
word_freq['over'] = 1
word_freq['body'] = 17

# Confirm that items are added
word_freq.items()
# Out:
# dict_items([('love', 25), ('conversation', 1), ('every', 6), ("we're", 1), ('plate', 1), ('sour', 1), ('jukebox', 1), ('now', 11), ('taxi', 1), ('fast', 1), ('bag', 1), ('man', 1), ('push', 3), ('baby', 14), ('going', 1), ('you', 16), ("don't", 2), ('one', 1), ('mind', 2), ('backseat', 1), ('friends', 1), ('then', 3), ('know', 2), ('begin', 1), ('start', 2), ('over', 1), ('body', 17)])

# %% [markdown]
# 6. Convert keys to a list and store in word_list

# %%
# Convert dictionary to list
word_list= list(word_freq.keys())

# Print the list of keys
print("Word list:\n", word_list)

type(word_list)
# Out:
# Word list:
#  ['love', 'conversation', 'every', "we're", 'plate', 'sour', 'jukebox', 'now', 'taxi', 'fast', 'bag', 'man', 'push', 'baby', 'going', 'you', "don't", 'one', 'mind', 'backseat', 'friends', 'then', 'know', 'begin', 'start', 'over', 'body']
# list

# %% [markdown]
# 7. First word and its frequency

# %%
# First element in the list
print("First word:", word_list[0])
print("Frequecy:", word_freq[word_list[0]])
# Out:
# First word: love
# Frequecy: 25

# %% [markdown]
# 8. Last word and its frequency

# %%
# Last word and frequency
print("Last word:", word_list[-1])
print("Frequency:", word_freq[word_list[-1]])
# Out:
# Last word: body
# Frequency: 17

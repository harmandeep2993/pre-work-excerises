# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Harmandeep Singh"
reason = """I like working with data and using it to solve real problems.
Data helps us understand patterns, make better decisions, and improve how things work.
I enjoy analyzing data, finding insights, and turning numbers into clear information.
AI and machine learning are especially interesting to me because they allow systems to learn from data and become smarter over time.
I also like that this field is very practical. The results can be used in real life, for example to improve business processes,
understand customer behavior, or support better decision-making.
This matches well with my analytical thinking and my goal to work in a data-driven role"""
fun_fact = "I can drink coffee and still fall asleep five minutes later"

print(f"Hi! My name is {name}.\nI’m excited to learn because {reason}.\nA fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Harmandeep Singh.
# I’m excited to learn because I like working with data and using it to solve real problems.
# Data helps us understand patterns, make better decisions, and improve how things work.
# I enjoy analyzing data, finding insights, and turning numbers into clear information.
# AI and machine learning are especially interesting to me because they allow systems to learn from data and become smarter over time.
# I also like that this field is very practical. The results can be used in real life, for example to improve business processes,
# understand customer behavior, or support better decision-making.
# This matches well with my analytical thinking and my goal to work in a data-driven role.
# A fun fact about me is: I can drink coffee and still fall asleep five minutes later.
